# %%
import pandas as pd

# --- Load datasets ---
clinical = pd.read_csv("clinical_breast_cancer.csv")
recurrence = pd.read_csv("breast_cancer_recurrence.csv")
diagnostic = pd.read_csv("breast_cancer_diagnostic.csv")

# %%
clinical.head(), clinical.shape
recurrence.head(), recurrence.shape
diagnostic.head(), diagnostic.shape
# Out:
# (         id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
#  0    842302         M        17.99         10.38          122.80     1001.0
#  1    842517         M        20.57         17.77          132.90     1326.0
#  2  84300903         M        19.69         21.25          130.00     1203.0
#  3  84348301         M        11.42         20.38           77.58      386.1
#  4  84358402         M        20.29         14.34          135.10     1297.0
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
#  0          0.11840           0.27760          0.3001              0.14710
#  1          0.08474           0.07864          0.0869              0.07017
#  2          0.10960           0.15990          0.1974              0.12790
#  3          0.14250           0.28390          0.2414              0.10520
#  4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
clinical.index.equals(diagnostic.index)
# Out:
# False

# %%
clinical.columns
diagnostic.columns
recurrence.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
import pandas as pd

combined = pd.read_csv("combined_breast_cancer_validated.csv")

# %%
combined = combined.loc[:, ~combined.columns.str.contains('^Unnamed')]

# %%
combined.head()
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5161 entries, 0 to 5160
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   symmetry_mean            1138 non-null   float64
#  1   target                   5161 non-null   int64
#  2   compactness_mean         1138 non-null   float64
#  3   A Stage                  4023 non-null   object
#  4   perimeter_worst          1138 non-null   float64
#  5   smoothness_se            1138 non-null   float64
#  6   Progesterone Status      4023 non-null   object
#  7   radius_se                1138 non-null   float64
#  8   Survival Months          4023 non-null   float64
#  9   compactness_worst        1138 non-null   float64
#  10  concavity_worst          1138 non-null   float64
#  11  Grade                    4023 non-null   object
#  12  N Stage                  4023 non-null   object
#  13  id                       1138 non-null   float64
# ...

# %%
import pandas as pd

combined = pd.read_csv("combined_breast_cancer_validated.csv")

# Remove unnamed junk columns
combined = combined.loc[:, ~combined.columns.str.contains('^Unnamed')]

combined.head()
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5161 entries, 0 to 5160
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   symmetry_mean            1138 non-null   float64
#  1   target                   5161 non-null   int64
#  2   compactness_mean         1138 non-null   float64
#  3   A Stage                  4023 non-null   object
#  4   perimeter_worst          1138 non-null   float64
#  5   smoothness_se            1138 non-null   float64
#  6   Progesterone Status      4023 non-null   object
#  7   radius_se                1138 non-null   float64
#  8   Survival Months          4023 non-null   float64
#  9   compactness_worst        1138 non-null   float64
#  10  concavity_worst          1138 non-null   float64
#  11  Grade                    4023 non-null   object
#  12  N Stage                  4023 non-null   object
#  13  id                       1138 non-null   float64
# ...

# %%
combined.columns
# Out:
# Index(['symmetry_mean', 'target', 'compactness_mean', 'A Stage',
#        'perimeter_worst', 'smoothness_se', 'Progesterone Status', 'radius_se',
#        'Survival Months', 'compactness_worst', 'concavity_worst', 'Grade',
#        'N Stage', 'id', 'fractal_dimension_mean', 'concave points_worst',
#        'perimeter_mean', 'radius_mean', 'area_se', 'T Stage ', 'texture_se',
#        'differentiate', 'smoothness_worst', 'concave points_se',
#        'fractal_dimension_worst', 'texture_worst', 'radius_worst',
#        'Regional Node Examined', 'Estrogen Status', 'concavity_mean',
#        'concave points_mean', 'Marital Status', 'perimeter_se', '6th Stage',
#        'Regional Node Positive', 'Race', 'symmetry_se', 'Age', 'Tumor Size',
#        'fractal_dimension_se', 'smoothness_mean', 'compactness_se',
#        'concavity_se', 'area_mean', 'symmetry_worst', 'texture_mean',
#        'area_worst', 'source'],
#       dtype='object')

# %%
combined.columns.tolist()
# Out:
# ['symmetry_mean',
#  'target',
#  'compactness_mean',
#  'A Stage',
#  'perimeter_worst',
#  'smoothness_se',
#  'Progesterone Status',
#  'radius_se',
#  'Survival Months',
#  'compactness_worst',
#  'concavity_worst',
#  'Grade',
#  'N Stage',
#  'id',
#  'fractal_dimension_mean',
#  'concave points_worst',
#  'perimeter_mean',
#  'radius_mean',
#  'area_se',
#  'T Stage ',
#  'texture_se',
#  'differentiate',
#  'smoothness_worst',
#  'concave points_se',
#  'fractal_dimension_worst',
#  'texture_worst',
#  'radius_worst',
#  'Regional Node Examined',
#  'Estrogen Status',
#  'concavity_mean',
#  'concave points_mean',
#  'Marital Status',
#  'perimeter_se',
#  '6th Stage',
#  'Regional Node Positive',
#  'Race',
#  'symmetry_se',
#  'Age',
#  'Tumor Size',
#  'fractal_dimension_se',
#  'smoothness_mean',
#  'compactness_se',
#  'concavity_se',
#  'area_mean',
#  'symmetry_worst',
#  'texture_mean',
#  'area_worst',
#  'source']

# %%
target_col = "target"

X = combined.drop(target_col, axis=1)
y = combined[target_col]

# %%
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns
categorical_features = X.select_dtypes(include=["object"]).columns

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

model = Pipeline(steps=[
    ("preprocess", preprocess),
    ("classifier", RandomForestClassifier(random_state=42))
])

# %%
model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['symmetry_mean', 'compactness_mean', 'perimeter_worst', 'smoothness_se',
#        'radius_se', 'Survival Months', 'compactness_worst', 'concavity_worst',
#        'id', 'fractal_dimension_mean', 'concave points_wo...
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
import joblib
joblib.dump(model, "breast_cancer_unified_model.pkl", protocol=4)
# Out:
# ['breast_cancer_unified_model.pkl']

# %%
import pandas as pd

# --- Load the final combined dataset ---
combined = pd.read_csv("combined_breast_cancer_validated.csv")

# Remove unnamed junk columns
combined = combined.loc[:, ~combined.columns.str.contains('^Unnamed')]

# Confirm structure
print(combined.shape)
print(combined.columns.tolist())
# Out:
# (5161, 48)
# ['symmetry_mean', 'target', 'compactness_mean', 'A Stage', 'perimeter_worst', 'smoothness_se', 'Progesterone Status', 'radius_se', 'Survival Months', 'compactness_worst', 'concavity_worst', 'Grade', 'N Stage', 'id', 'fractal_dimension_mean', 'concave points_worst', 'perimeter_mean', 'radius_mean', 'area_se', 'T Stage ', 'texture_se', 'differentiate', 'smoothness_worst', 'concave points_se', 'fractal_dimension_worst', 'texture_worst', 'radius_worst', 'Regional Node Examined', 'Estrogen Status', 'concavity_mean', 'concave points_mean', 'Marital Status', 'perimeter_se', '6th Stage', 'Regional Node Positive', 'Race', 'symmetry_se', 'Age', 'Tumor Size', 'fractal_dimension_se', 'smoothness_mean', 'compactness_se', 'concavity_se', 'area_mean', 'symmetry_worst', 'texture_mean', 'area_worst', 'source']

# %%
target_col = "target"

X = combined.drop(target_col, axis=1)
y = combined[target_col]

# %%
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns
categorical_features = X.select_dtypes(include=["object"]).columns

numeric_features, categorical_features
# Out:
# (Index(['symmetry_mean', 'compactness_mean', 'perimeter_worst', 'smoothness_se',
#         'radius_se', 'Survival Months', 'compactness_worst', 'concavity_worst',
#         'id', 'fractal_dimension_mean', 'concave points_worst',
#         'perimeter_mean', 'radius_mean', 'area_se', 'texture_se',
#         'smoothness_worst', 'concave points_se', 'fractal_dimension_worst',
#         'texture_worst', 'radius_worst', 'Regional Node Examined',
#         'concavity_mean', 'concave points_mean', 'perimeter_se',
#         'Regional Node Positive', 'symmetry_se', 'Age', 'Tumor Size',
#         'fractal_dimension_se', 'smoothness_mean', 'compactness_se',
#         'concavity_se', 'area_mean', 'symmetry_worst', 'texture_mean',
#         'area_worst'],
#        dtype='object'),
#  Index(['A Stage', 'Progesterone Status', 'Grade', 'N Stage', 'T Stage ',
#         'differentiate', 'Estrogen Status', 'Marital Status', '6th Stage',
#         'Race', 'source'],
#        dtype='object'))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

model = Pipeline(steps=[
    ("preprocess", preprocess),
    ("classifier", RandomForestClassifier(random_state=42))
])

# %%
model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['symmetry_mean', 'compactness_mean', 'perimeter_worst', 'smoothness_se',
#        'radius_se', 'Survival Months', 'compactness_worst', 'concavity_worst',
#        'id', 'fractal_dimension_mean', 'concave points_wo...
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
import joblib
joblib.dump(model, "breast_cancer_unified_model.pkl", protocol=4)
# Out:
# ['breast_cancer_unified_model.pkl']

# %%
joblib.dump(model, "breast_cancer_unified_model.pkl", protocol=4)
# Out:
# ['breast_cancer_unified_model.pkl']

# %%
import os
os.getcwd()
# Out:
# '/Users/mannetymowa/Breast Cancer Classification Machine'

# %%
import joblib
joblib.dump(model, "breast_cancer_unified_model.pkl", protocol=4)
# Out:
# ['breast_cancer_unified_model.pkl']

# %%
model_test = joblib.load("breast_cancer_unified_model.pkl")
print("Model loaded successfully in Python 3.7!")
# Out:
# Model loaded successfully in Python 3.7!

# %%
import joblib
joblib.dump(model, "breast_cancer_unified_model.pkl", protocol=4)
# Out:
# ['breast_cancer_unified_model.pkl']

# %%
joblib.load("breast_cancer_unified_model.pkl")
print("Loaded successfully in Python 3.7")
# Out:
# Loaded successfully in Python 3.7

# %%
import joblib
joblib.dump(model, "breast_cancer_unified_model.pkl", protocol=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import joblib
# ----> 2 joblib.dump(model, "breast_cancer_unified_model.pkl", protocol=4)
#
# NameError: name 'model' is not defined

# %%
import pandas as pd

combined = pd.read_csv("combined_breast_cancer_validated.csv")
combined = combined.loc[:, ~combined.columns.str.contains('^Unnamed')]

# %%
target_col = "target"

X = combined.drop(target_col, axis=1)
y = combined[target_col]

# %%
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns
categorical_features = X.select_dtypes(include=["object"]).columns

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

model = Pipeline(steps=[
    ("preprocess", preprocess),
    ("classifier", RandomForestClassifier(random_state=42))
])

# %%
model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['symmetry_mean', 'compactness_mean', 'perimeter_worst', 'smoothness_se',
#        'radius_se', 'Survival Months', 'compactness_worst', 'concavity_worst',
#        'id', 'fractal_dimension_mean', 'concave points_wo...
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
import joblib
joblib.dump(model, "breast_cancer_unified_model.pkl", protocol=4)
# Out:
# ['breast_cancer_unified_model.pkl']

# %%
joblib.load("breast_cancer_unified_model.pkl")
print("Model loads successfully in Python 3.7")
# Out:
# Model loads successfully in Python 3.7

# %%
import sys
print(sys.version)
# Out:
# 3.11.2 (v3.11.2:878ead1ac1, Feb  7 2023, 10:02:41) [Clang 13.0.0 (clang-1300.0.29.30)]

# %%
import sys
print(sys.version)
# Out:
# 3.7.16 (default, Jan 17 2023, 09:28:58)
# [Clang 14.0.6 ]

# %%
import joblib
joblib.dump(model, "breast_cancer_unified_model.pkl", protocol=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/n3/yn64vs310dnclhpbr_1d3r500000gn/T/ipykernel_51127/2818754999.py in <module>
#       1 import joblib
# ----> 2 joblib.dump(model, "breast_cancer_unified_model.pkl", protocol=4)
#
# NameError: name 'model' is not defined

# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
import joblib

# %%
combined = pd.read_csv("combined_breast_cancer_validated.csv")
combined = combined.loc[:, ~combined.columns.str.contains('^Unnamed')]

# %%
target_col = "target"
X = combined.drop(target_col, axis=1)
y = combined[target_col]

# %%
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns
categorical_features = X.select_dtypes(include=["object"]).columns

# %%
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

model = Pipeline(steps=[
    ("preprocess", preprocess),
    ("classifier", RandomForestClassifier(random_state=42))
])

# %%
model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['symmetry_mean', 'compactness_mean', 'perimeter_worst', 'smoothness_se',
#        'radius_se', 'Survival Months', 'compactness_worst', 'concavity_worst',
#        'id', 'fractal_dimension_mean', 'concave points_wo...
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
joblib.dump(model, "breast_cancer_unified_model.pkl", protocol=4)
# Out:
# ['breast_cancer_unified_model.pkl']

# %%
joblib.load("breast_cancer_unified_model.pkl")
print("Model loads successfully in Python 3.7")
# Out:
# Model loads successfully in Python 3.7
